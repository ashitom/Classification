# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
from matplotlib import pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve,roc_auc_score
from sklearn.metrics import confusion_matrix, accuracy_score,ConfusionMatrixDisplay
from IPython.core.interactiveshell import InteractiveShell
#setting to print all executed lines
InteractiveShell.ast_node_interactivity = "all"
import kds
from statsmodels.stats.outliers_influence import variance_inflation_factor

# %%
#import dataset
df = pd.read_csv('enrollment.csv')

# %%
#Observe the data before wrangling
df.head()
df.describe(include='all')
df.info()
# Out:
#   ETHNICITY TERRITORY ACADEMIC_INTEREST_1 ACADEMIC_INTEREST_2  Enroll  \
# 0         C         N                 NaN                 NaN       0
# 1         C         N                 NaN                 NaN       0
# 2         B         N                 NaN                 NaN       0
# 3       NaN         N                 NaN                 NaN       0
# 4       NaN         N                 NaN                 NaN       0
#
#   CONTACT_DATE  TOTAL_CONTACTS  SELF_INIT_CNTCTS  TRAVEL_INIT_CNTCTS  \
# 0      21MAY14               1                 0                   0
# 1      15FEB13               1                 0                   0
# 2      09JUN12               2                 2                   0
# 3      25NOV11               3                 2                   1
# 4      06DEC10               1                 1                   0
#
#    SOLICITED_CNTCTS  ...  premiere  interest stucell init_span   int1rat  \
# 0                 1  ...         0         0       0         4  0.017183
# 1                 1  ...         0         0       1        19  0.017183
# 2                 0  ...         0         0       0        27  0.017183
# 3                 0  ...         0         0       1        34  0.017183
# 4                 0  ...         0         0       1        45  0.017183
#
#    int2rat    hscrat  avg_income  distance  Instate
# 0  0.02038  0.037652         NaN       NaN        N
# 1  0.02038  0.037652         NaN       NaN        N
# 2  0.02038  0.037652         NaN       NaN        N
# 3  0.02038  0.037652         NaN       NaN        N
# 4  0.02038  0.037652         NaN       NaN        N
#
# [5 rows x 29 columns]
#        ETHNICITY TERRITORY ACADEMIC_INTEREST_1 ACADEMIC_INTEREST_2  \
# count      71772     91481               44283               24879
# unique         7        11                 211                 208
# top            C         2                 MED                 MED
# freq       31750     14621                6113                2350
# mean         NaN       NaN                 NaN                 NaN
# std          NaN       NaN                 NaN                 NaN
# min          NaN       NaN                 NaN                 NaN
# 25%          NaN       NaN                 NaN                 NaN
# 50%          NaN       NaN                 NaN                 NaN
# 75%          NaN       NaN                 NaN                 NaN
# max          NaN       NaN                 NaN                 NaN
#
#               Enroll CONTACT_DATE  TOTAL_CONTACTS  SELF_INIT_CNTCTS  \
# count   91482.000000        91482    91482.000000      91482.000000
# unique           NaN         1113             NaN               NaN
# top              NaN      30JUN13             NaN               NaN
# freq             NaN         6644             NaN               NaN
# mean        0.031350          NaN        2.166098          1.214119
# std         0.174264          NaN        1.852537          1.666529
# min         0.000000          NaN        1.000000          0.000000
# 25%         0.000000          NaN        1.000000          0.000000
# 50%         0.000000          NaN        2.000000          1.000000
# 75%         0.000000          NaN        2.000000          1.000000
# max         1.000000          NaN       58.000000         56.000000
#
#         TRAVEL_INIT_CNTCTS  SOLICITED_CNTCTS  ...      premiere      interest  \
# count         91482.000000      91482.000000  ...  91482.000000  91482.000000
# unique                 NaN               NaN  ...           NaN           NaN
# top                    NaN               NaN  ...           NaN           NaN
# freq                   NaN               NaN  ...           NaN           NaN
# mean              0.364815          0.547222  ...      0.028913      0.053639
# std               0.557067          0.649426  ...      0.167562      0.242052
# min               0.000000          0.000000  ...      0.000000      0.000000
# 25%               0.000000          0.000000  ...      0.000000      0.000000
# 50%               0.000000          0.000000  ...      0.000000      0.000000
# 75%               1.000000          1.000000  ...      0.000000      0.000000
# max               8.000000          9.000000  ...      1.000000      3.000000
#
#              stucell     init_span       int1rat       int2rat        hscrat  \
# count   91482.000000  91482.000000  91482.000000  91482.000000  91482.000000
# unique           NaN           NaN           NaN           NaN           NaN
# top              NaN           NaN           NaN           NaN           NaN
# freq             NaN           NaN           NaN           NaN           NaN
# mean        0.489922     19.686157      0.037091      0.042896      0.037652
# std         0.499901      8.722109      0.024026      0.025244      0.057399
# min         0.000000   -216.000000      0.000000      0.000000      0.000000
# 25%         0.000000     13.000000      0.017183      0.020380      0.000000
# 50%         0.000000     19.000000      0.042105      0.056670      0.033333
# 75%         1.000000     25.000000      0.049270      0.056670      0.048035
# max         1.000000    228.000000      1.000000      1.000000      1.000000
#
#            avg_income      distance  Instate
# count    70553.000000  72014.000000    91482
# unique            NaN           NaN        2
# top               NaN           NaN        Y
# freq              NaN           NaN    56760
# mean     47315.334146    380.427645      NaN
# std      20608.888129    397.978831      NaN
# min       4940.000000      0.417124      NaN
# 25%      32045.000000    114.471414      NaN
# 50%      42324.000000    183.546674      NaN
# 75%      57314.000000    539.432855      NaN
# max     200001.000000   4798.898626      NaN
#
# [11 rows x 29 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91482 entries, 0 to 91481
# Data columns (total 29 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   ETHNICITY            71772 non-null  object
#  1   TERRITORY            91481 non-null  object
#  2   ACADEMIC_INTEREST_1  44283 non-null  object
#  3   ACADEMIC_INTEREST_2  24879 non-null  object
#  4   Enroll               91482 non-null  int64
#  5   CONTACT_DATE         91482 non-null  object
#  6   TOTAL_CONTACTS       91482 non-null  int64
#  7   SELF_INIT_CNTCTS     91482 non-null  int64
#  8   TRAVEL_INIT_CNTCTS   91482 non-null  int64
#  9   SOLICITED_CNTCTS     91482 non-null  int64
#  10  REFERRAL_CNTCTS      91482 non-null  int64
#  11  CAMPUS_VISIT         91482 non-null  int64
#  12  CONTACT_CODE1        91339 non-null  object
#  13  LEVEL_YEAR           91482 non-null  object
#  14  IRSCHOOL             76172 non-null  object
#  15  satscore             27003 non-null  float64
#  16  sex                  87649 non-null  float64
#  17  mailq                91482 non-null  int64
#  18  telecq               20602 non-null  float64
#  19  premiere             91482 non-null  int64
#  20  interest             91482 non-null  int64
#  21  stucell              91482 non-null  int64
#  22  init_span            91482 non-null  int64
#  23  int1rat              91482 non-null  float64
#  24  int2rat              91482 non-null  float64
#  25  hscrat               91482 non-null  float64
#  26  avg_income           70553 non-null  float64
#  27  distance             72014 non-null  float64
#  28  Instate              91482 non-null  object
# dtypes: float64(8), int64(12), object(9)
# memory usage: 20.2+ MB

# %%
#There are NaN values in the dataset, hence missing values imputation is required
# print the NaN values and plot them on a bar chart
df.isna().sum()
df.isna().sum().plot(kind='bar')
# Out:
# ETHNICITY              19710
# TERRITORY                  1
# ACADEMIC_INTEREST_1    47199
# ACADEMIC_INTEREST_2    66603
# Enroll                     0
# CONTACT_DATE               0
# TOTAL_CONTACTS             0
# SELF_INIT_CNTCTS           0
# TRAVEL_INIT_CNTCTS         0
# SOLICITED_CNTCTS           0
# REFERRAL_CNTCTS            0
# CAMPUS_VISIT               0
# CONTACT_CODE1            143
# LEVEL_YEAR                 0
# IRSCHOOL               15310
# satscore               64479
# sex                     3833
# mailq                      0
# telecq                 70880
# premiere                   0
# interest                   0
# stucell                    0
# init_span                  0
# int1rat                    0
# int2rat                    0
# hscrat                     0
# avg_income             20929
# distance               19468
# Instate                    0
# dtype: int64
# <AxesSubplot:>

# %%
#in addition to the columns recommended to be dropped from the dataset, satscore and telecq have huge values of NaN values as can be seen above
#below these columns are also dropped from the dataset and the new plot of NaN values is shown
df.drop(['ACADEMIC_INTEREST_1','ACADEMIC_INTEREST_2','IRSCHOOL','CONTACT_CODE1','CONTACT_DATE','satscore','telecq'], axis=1, inplace=True)
df.isna().sum().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#View the list of columns that still have NaN
df.loc[:,df.isna().any()].columns.values.tolist()
# Out:
# ['ETHNICITY', 'TERRITORY', 'sex', 'avg_income', 'distance']

# %%
#Take a value count for the non-numeric fields
df['TERRITORY'].value_counts(sort=True, dropna=False)
df['ETHNICITY'].value_counts(sort=True, dropna=False)
# Out:
# 2      14621
# 5      14033
# 7      11796
# 4      10611
# 3       9261
# 1       9219
# 6       9037
# 8       6644
# A       3284
# N       2970
# 000        5
# NaN        1
# Name: TERRITORY, dtype: int64
# C      31750
# NaN    19710
# N      14793
# H       9989
# B       8477
# A       3336
# O       2705
# I        722
# Name: ETHNICITY, dtype: int64

# %%
#TERRITORY has only 1 value as NaN hence the row will be deleted
df.dropna(subset=['TERRITORY'], inplace=True)
#TERRITORY also has 5 rows with value 000 which is invalid in the value set because it is not an alphabet. It will be removed
df = df[df.TERRITORY != '000']
#reconfirm TERRITORY Column
df['TERRITORY'].value_counts(sort=True, dropna=False)
#ETHNICITY has significant number of NaN values which are imputed by the most occuring value
df['ETHNICITY'].fillna(df['ETHNICITY'].mode()[0], inplace=True)
#Sex, avg_income and distance are numeric fields. They are imputed by their mean
Num_nan = ['sex', 'avg_income', 'distance']
for col in Num_nan:
    df[col].fillna(df[col].mean(), inplace=True)
df.isna().sum()
# Out:
# 2    14621
# 5    14033
# 7    11796
# 4    10611
# 3     9261
# 1     9219
# 6     9037
# 8     6644
# A     3284
# N     2970
# Name: TERRITORY, dtype: int64
# ETHNICITY             0
# TERRITORY             0
# Enroll                0
# TOTAL_CONTACTS        0
# SELF_INIT_CNTCTS      0
# TRAVEL_INIT_CNTCTS    0
# SOLICITED_CNTCTS      0
# REFERRAL_CNTCTS       0
# CAMPUS_VISIT          0
# LEVEL_YEAR            0
# sex                   0
# mailq                 0
# premiere              0
# interest              0
# stucell               0
# init_span             0
# int1rat               0
# int2rat               0
# hscrat                0
# avg_income            0
# distance              0
# Instate               0
# dtype: int64

# %%
# separate numerical variables AND categorical variables for the X variables
cat_var =['ETHNICITY','TERRITORY','LEVEL_YEAR','sex','mailq','Instate','premiere','stucell']
num_var = ['TOTAL_CONTACTS','SELF_INIT_CNTCTS','TRAVEL_INIT_CNTCTS','SOLICITED_CNTCTS',
'REFERRAL_CNTCTS','CAMPUS_VISIT','interest', 'init_span',
'int1rat','int2rat', 'hscrat', 'avg_income', 'distance']

# %%
#generate dummy variables for the categorical variables
dummy_df =pd.get_dummies(df[cat_var])
dummy_names = dummy_df.columns
dummy_df.describe()
dummy_names
# Out:
#                 sex         mailq      premiere       stucell   ETHNICITY_A  \
# count  91476.000000  91476.000000  91476.000000  91476.000000  91476.000000
# mean       0.631619      4.084317      0.028915      0.489910      0.036469
# std        0.472154      1.440357      0.167568      0.499901      0.187454
# min        0.000000      1.000000      0.000000      0.000000      0.000000
# 25%        0.000000      3.000000      0.000000      0.000000      0.000000
# 50%        1.000000      5.000000      0.000000      0.000000      0.000000
# 75%        1.000000      5.000000      0.000000      1.000000      0.000000
# max        1.000000      5.000000      1.000000      1.000000      1.000000
#
#         ETHNICITY_B   ETHNICITY_C   ETHNICITY_H   ETHNICITY_I   ETHNICITY_N  \
# count  91476.000000  91476.000000  91476.000000  91476.000000  91476.000000
# mean       0.092647      0.562519      0.109198      0.007893      0.161704
# std        0.289939      0.496079      0.311889      0.088491      0.368181
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      1.000000      0.000000      0.000000      0.000000
# 75%        0.000000      1.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#        ...   TERRITORY_4   TERRITORY_5   TERRITORY_6   TERRITORY_7  \
# count  ...  91476.000000  91476.000000  91476.000000  91476.000000
# mean   ...      0.115998      0.153406      0.098791      0.128952
# std    ...      0.320224      0.360381      0.298383      0.335148
# min    ...      0.000000      0.000000      0.000000      0.000000
# 25%    ...      0.000000      0.000000      0.000000      0.000000
# 50%    ...      0.000000      0.000000      0.000000      0.000000
# 75%    ...      0.000000      0.000000      0.000000      0.000000
# max    ...      1.000000      1.000000      1.000000      1.000000
#
#         TERRITORY_8   TERRITORY_A   TERRITORY_N  LEVEL_YEAR_FR14  \
# count  91476.000000  91476.000000  91476.000000          91476.0
# mean       0.072631      0.035900      0.032468              1.0
# std        0.259531      0.186042      0.177239              0.0
# min        0.000000      0.000000      0.000000              1.0
# 25%        0.000000      0.000000      0.000000              1.0
# 50%        0.000000      0.000000      0.000000              1.0
# 75%        0.000000      0.000000      0.000000              1.0
# max        1.000000      1.000000      1.000000              1.0
#
#           Instate_N     Instate_Y
# count  91476.000000  91476.000000
# mean       0.379542      0.620458
# std        0.485276      0.485276
# min        0.000000      0.000000
# 25%        0.000000      0.000000
# 50%        0.000000      1.000000
# 75%        1.000000      1.000000
# max        1.000000      1.000000
#
# [8 rows x 24 columns]
# Index(['sex', 'mailq', 'premiere', 'stucell', 'ETHNICITY_A', 'ETHNICITY_B',
#        'ETHNICITY_C', 'ETHNICITY_H', 'ETHNICITY_I', 'ETHNICITY_N',
#        'ETHNICITY_O', 'TERRITORY_1', 'TERRITORY_2', 'TERRITORY_3',
#        'TERRITORY_4', 'TERRITORY_5', 'TERRITORY_6', 'TERRITORY_7',
#        'TERRITORY_8', 'TERRITORY_A', 'TERRITORY_N', 'LEVEL_YEAR_FR14',
#        'Instate_N', 'Instate_Y'],
#       dtype='object')

# %%
#Construct X variables
x = pd.concat([df[num_var],dummy_df[dummy_names]],axis=1)
x.describe(include='all')
# Out:
#        TOTAL_CONTACTS  SELF_INIT_CNTCTS  TRAVEL_INIT_CNTCTS  SOLICITED_CNTCTS  \
# count    91476.000000      91476.000000        91476.000000      91476.000000
# mean         2.166153          1.214122            0.364839          0.547247
# std          1.852576          1.666568            0.557077          0.649433
# min          1.000000          0.000000            0.000000          0.000000
# 25%          1.000000          0.000000            0.000000          0.000000
# 50%          2.000000          1.000000            0.000000          0.000000
# 75%          2.000000          1.000000            1.000000          1.000000
# max         58.000000         56.000000            8.000000          9.000000
#
#        REFERRAL_CNTCTS  CAMPUS_VISIT      interest     init_span  \
# count     91476.000000  91476.000000  91476.000000  91476.000000
# mean          0.039901      0.034676      0.053642     19.686967
# std           0.226198      0.187328      0.242059      8.721500
# min           0.000000      0.000000      0.000000   -216.000000
# 25%           0.000000      0.000000      0.000000     13.000000
# 50%           0.000000      0.000000      0.000000     19.000000
# 75%           0.000000      0.000000      0.000000     25.000000
# max           5.000000      2.000000      3.000000    228.000000
#
#             int1rat       int2rat  ...   TERRITORY_4   TERRITORY_5  \
# count  91476.000000  91476.000000  ...  91476.000000  91476.000000
# mean       0.037091      0.042896  ...      0.115998      0.153406
# std        0.024026      0.025244  ...      0.320224      0.360381
# min        0.000000      0.000000  ...      0.000000      0.000000
# 25%        0.017183      0.020380  ...      0.000000      0.000000
# 50%        0.042105      0.056670  ...      0.000000      0.000000
# 75%        0.049270      0.056670  ...      0.000000      0.000000
# max        1.000000      1.000000  ...      1.000000      1.000000
#
#         TERRITORY_6   TERRITORY_7   TERRITORY_8   TERRITORY_A   TERRITORY_N  \
# count  91476.000000  91476.000000  91476.000000  91476.000000  91476.000000
# mean       0.098791      0.128952      0.072631      0.035900      0.032468
# std        0.298383      0.335148      0.259531      0.186042      0.177239
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#        LEVEL_YEAR_FR14     Instate_N     Instate_Y
# count          91476.0  91476.000000  91476.000000
# mean               1.0      0.379542      0.620458
# std                0.0      0.485276      0.485276
# min                1.0      0.000000      0.000000
# 25%                1.0      0.000000      0.000000
# 50%                1.0      0.000000      1.000000
# 75%                1.0      1.000000      1.000000
# max                1.0      1.000000      1.000000
#
# [8 rows x 37 columns]

# %%
#check for correlation
x.corr()
# Out:
#                     TOTAL_CONTACTS  SELF_INIT_CNTCTS  TRAVEL_INIT_CNTCTS  \
# TOTAL_CONTACTS            1.000000          0.923759            0.229478
# SELF_INIT_CNTCTS          0.923759          1.000000            0.059156
# TRAVEL_INIT_CNTCTS        0.229478          0.059156            1.000000
# SOLICITED_CNTCTS          0.245079          0.005819           -0.339057
# REFERRAL_CNTCTS           0.115086          0.035479           -0.045777
# CAMPUS_VISIT              0.298846          0.339548            0.002800
# interest                  0.287361          0.283897            0.105856
# init_span                 0.085256         -0.041564            0.116931
# int1rat                   0.195788          0.198893            0.160840
# int2rat                   0.182274          0.187614            0.179039
# hscrat                    0.195483          0.231157           -0.026882
# avg_income                0.134910          0.166142           -0.046230
# distance                 -0.122030         -0.117026           -0.134591
# sex                       0.040976          0.014408            0.025271
# mailq                    -0.204280         -0.114784           -0.706158
# premiere                  0.490955          0.506728            0.061131
# stucell                   0.361526          0.320277            0.033436
# ETHNICITY_A               0.078564          0.089991           -0.015085
# ETHNICITY_B               0.023138          0.026817            0.000676
# ETHNICITY_C              -0.062637         -0.047444           -0.009831
# ETHNICITY_H               0.044997          0.040994            0.153184
# ETHNICITY_I               0.001470         -0.003158           -0.022046
# ETHNICITY_N              -0.005669         -0.026818           -0.075882
# ETHNICITY_O              -0.014402         -0.022079           -0.061268
# TERRITORY_1               0.038268          0.035866            0.054271
# TERRITORY_2              -0.060922         -0.078737           -0.080128
# TERRITORY_3               0.050456          0.064433            0.046529
# TERRITORY_4               0.011516          0.020729            0.010093
# TERRITORY_5              -0.041699         -0.049250            0.003442
# TERRITORY_6               0.028389          0.022445            0.004337
# TERRITORY_7              -0.002587         -0.001170           -0.005776
# TERRITORY_8               0.071396          0.067189            0.022760
# TERRITORY_A              -0.040842         -0.046406           -0.016785
# TERRITORY_N              -0.065504         -0.030346           -0.043022
# LEVEL_YEAR_FR14                NaN               NaN                 NaN
# Instate_N                -0.150889         -0.145825           -0.223375
# Instate_Y                 0.150889          0.145825            0.223375
#
#                     SOLICITED_CNTCTS  REFERRAL_CNTCTS  CAMPUS_VISIT  interest  \
# TOTAL_CONTACTS              0.245079         0.115086      0.298846  0.287361
# SELF_INIT_CNTCTS            0.005819         0.035479      0.339548  0.283897
# TRAVEL_INIT_CNTCTS         -0.339057        -0.045777      0.002800  0.105856
# SOLICITED_CNTCTS            1.000000        -0.071772     -0.026856 -0.008995
# REFERRAL_CNTCTS            -0.071772         1.000000      0.016107  0.026995
# CAMPUS_VISIT               -0.026856         0.016107      1.000000  0.116649
# interest                   -0.008995         0.026995      0.116649  1.000000
# init_span                   0.234363         0.043553      0.043004 -0.005903
# int1rat                    -0.097126         0.020860      0.074253  0.082313
# int2rat                    -0.122274         0.020620      0.070321  0.081634
# hscrat                     -0.020879         0.024081      0.128340  0.069981
# avg_income                 -0.000017        -0.005155      0.111515  0.025576
# distance                    0.073895        -0.017805     -0.052927 -0.045683
# sex                         0.059607        -0.003768      0.007381  0.003143
# mailq                       0.305282         0.035374     -0.145754 -0.155669
# premiere                    0.028984         0.053778      0.081940  0.139910
# stucell                     0.196754        -0.046132      0.111135  0.133708
# ETHNICITY_A                 0.013504        -0.021170      0.004459  0.017117
# ETHNICITY_B                 0.008075        -0.032864     -0.020505  0.030278
# ETHNICITY_C                -0.074437         0.074607      0.054900  0.003616
# ETHNICITY_H                -0.099656        -0.024882     -0.012607  0.036224
# ETHNICITY_I                 0.031556        -0.000988     -0.007937 -0.002414
# ETHNICITY_N                 0.130032        -0.035208     -0.039455 -0.062249
# ETHNICITY_O                 0.073602        -0.015957     -0.017500 -0.011491
# TERRITORY_1                -0.024384        -0.014746      0.014602  0.011922
# TERRITORY_2                 0.080923         0.045975     -0.040130 -0.018401
# TERRITORY_3                -0.061387         0.000236      0.018934  0.025335
# TERRITORY_4                -0.022700        -0.018019      0.002926  0.015626
# TERRITORY_5                 0.010579        -0.017425     -0.026007 -0.002101
# TERRITORY_6                 0.014133         0.015940      0.021247  0.007300
# TERRITORY_7                 0.000988        -0.001107     -0.020379 -0.001451
# TERRITORY_8                 0.010967         0.002215      0.072992 -0.009292
# TERRITORY_A                 0.020977        -0.011439     -0.021918 -0.023101
# TERRITORY_N                -0.065658        -0.018408     -0.007569 -0.020975
# LEVEL_YEAR_FR14                  NaN              NaN           NaN       NaN
# Instate_N                   0.141391        -0.017162     -0.048452 -0.061182
# Instate_Y                  -0.141391         0.017162      0.048452  0.061182
#
#                     init_span   int1rat   int2rat  ...  TERRITORY_4  \
# TOTAL_CONTACTS       0.085256  0.195788  0.182274  ...     0.011516
# SELF_INIT_CNTCTS    -0.041564  0.198893  0.187614  ...     0.020729
# TRAVEL_INIT_CNTCTS   0.116931  0.160840  0.179039  ...     0.010093
# SOLICITED_CNTCTS     0.234363 -0.097126 -0.122274  ...    -0.022700
# REFERRAL_CNTCTS      0.043553  0.020860  0.020620  ...    -0.018019
# CAMPUS_VISIT         0.043004  0.074253  0.070321  ...     0.002926
# interest            -0.005903  0.082313  0.081634  ...     0.015626
# init_span            1.000000 -0.083767 -0.095204  ...    -0.001493
# int1rat             -0.083767  1.000000  0.498630  ...     0.055244
# int2rat             -0.095204  0.498630  1.000000  ...     0.060299
# hscrat              -0.054469  0.133797  0.138279  ...     0.015659
# avg_income          -0.024922  0.049784  0.043995  ...     0.035706
# distance             0.001375 -0.396629 -0.429326  ...    -0.068920
# sex                  0.070605  0.004427 -0.020747  ...     0.005781
# mailq               -0.074741 -0.165130 -0.175113  ...    -0.002695
# premiere             0.022478  0.123137  0.120848  ...     0.018781
# stucell              0.070911  0.011219  0.004457  ...    -0.003581
# ETHNICITY_A         -0.040332  0.023486  0.020888  ...    -0.020755
# ETHNICITY_B         -0.009930 -0.001843 -0.001569  ...    -0.042986
# ETHNICITY_C         -0.005370 -0.061790 -0.062212  ...    -0.014788
# ETHNICITY_H         -0.054778  0.116953  0.131281  ...     0.068115
# ETHNICITY_I          0.017904 -0.025287 -0.030153  ...    -0.010706
# ETHNICITY_N          0.065874 -0.013866 -0.019822  ...     0.011605
# ETHNICITY_O          0.025681 -0.013867 -0.021118  ...    -0.005194
# TERRITORY_1         -0.028968  0.169234  0.184083  ...    -0.121270
# TERRITORY_2          0.069528 -0.185907 -0.195443  ...    -0.157998
# TERRITORY_3         -0.029673  0.176572  0.186098  ...    -0.121577
# TERRITORY_4         -0.001493  0.055244  0.060299  ...     1.000000
# TERRITORY_5         -0.001722 -0.052872 -0.058885  ...    -0.154199
# TERRITORY_6         -0.012632  0.110257  0.113930  ...    -0.119934
# TERRITORY_7          0.010250 -0.010436 -0.004116  ...    -0.139377
# TERRITORY_8          0.000438 -0.030889 -0.039095  ...    -0.101375
# TERRITORY_A          0.017794 -0.154244 -0.170483  ...    -0.069901
# TERRITORY_N         -0.055284 -0.154637 -0.162331  ...    -0.066357
# LEVEL_YEAR_FR14           NaN       NaN       NaN  ...          NaN
# Instate_N            0.069467 -0.648097 -0.697598  ...    -0.081135
# Instate_Y           -0.069467  0.648097  0.697598  ...     0.081135
#
#                     TERRITORY_5  TERRITORY_6  TERRITORY_7  TERRITORY_8  \
# TOTAL_CONTACTS        -0.041699     0.028389    -0.002587     0.071396
# SELF_INIT_CNTCTS      -0.049250     0.022445    -0.001170     0.067189
# TRAVEL_INIT_CNTCTS     0.003442     0.004337    -0.005776     0.022760
# SOLICITED_CNTCTS       0.010579     0.014133     0.000988     0.010967
# REFERRAL_CNTCTS       -0.017425     0.015940    -0.001107     0.002215
# CAMPUS_VISIT          -0.026007     0.021247    -0.020379     0.072992
# interest              -0.002101     0.007300    -0.001451    -0.009292
# init_span             -0.001722    -0.012632     0.010250     0.000438
# int1rat               -0.052872     0.110257    -0.010436    -0.030889
# int2rat               -0.058885     0.113930    -0.004116    -0.039095
# hscrat                -0.075706     0.046149    -0.029372     0.089999
# avg_income            -0.172066     0.042960    -0.008601     0.070779
# distance               0.089257    -0.148767     0.107269     0.057117
# sex                   -0.000234    -0.001746     0.006990    -0.023289
# mailq                  0.004439    -0.010886     0.018805    -0.008691
# premiere              -0.038153     0.023766    -0.015977     0.026115
# stucell               -0.030699    -0.007352     0.014683     0.029410
# ETHNICITY_A           -0.032326    -0.006170     0.001186    -0.003213
# ETHNICITY_B           -0.061322    -0.014311    -0.024060    -0.047440
# ETHNICITY_C            0.010528     0.034454    -0.033039     0.031469
# ETHNICITY_H            0.055013    -0.044970     0.075289    -0.005741
# ETHNICITY_I            0.061101    -0.009244    -0.021049    -0.008777
# ETHNICITY_N           -0.016329     0.008228     0.007844     0.007624
# ETHNICITY_O            0.012183     0.000167    -0.008051    -0.008819
# TERRITORY_1           -0.142508    -0.110841    -0.128810    -0.093689
# TERRITORY_2           -0.185668    -0.144410    -0.167821    -0.122064
# TERRITORY_3           -0.142869    -0.111122    -0.129136    -0.093927
# TERRITORY_4           -0.154199    -0.119934    -0.139377    -0.101375
# TERRITORY_5            1.000000    -0.140939    -0.163786    -0.119129
# TERRITORY_6           -0.140939     1.000000    -0.127391    -0.092658
# TERRITORY_7           -0.163786    -0.127391     1.000000    -0.107678
# TERRITORY_8           -0.119129    -0.092658    -0.107678     1.000000
# TERRITORY_A           -0.082143    -0.063890    -0.074247    -0.054004
# TERRITORY_N           -0.077979    -0.060651    -0.070483    -0.051266
# LEVEL_YEAR_FR14             NaN          NaN          NaN          NaN
# Instate_N              0.076567    -0.164353     0.014043     0.071291
# Instate_Y             -0.076567     0.164353    -0.014043    -0.071291
#
#                     TERRITORY_A  TERRITORY_N  LEVEL_YEAR_FR14  Instate_N  \
# TOTAL_CONTACTS        -0.040842    -0.065504              NaN  -0.150889
# SELF_INIT_CNTCTS      -0.046406    -0.030346              NaN  -0.145825
# TRAVEL_INIT_CNTCTS    -0.016785    -0.043022              NaN  -0.223375
# SOLICITED_CNTCTS       0.020977    -0.065658              NaN   0.141391
# REFERRAL_CNTCTS       -0.011439    -0.018408              NaN  -0.017162
# CAMPUS_VISIT          -0.021918    -0.007569              NaN  -0.048452
# interest              -0.023101    -0.020975              NaN  -0.061182
# init_span              0.017794    -0.055284              NaN   0.069467
# int1rat               -0.154244    -0.154637              NaN  -0.648097
# int2rat               -0.170483    -0.162331              NaN  -0.697598
# hscrat                -0.051351     0.004242              NaN  -0.147477
# avg_income             0.067389    -0.000619              NaN  -0.018108
# distance               0.376461     0.006575              NaN   0.629321
# sex                    0.016582    -0.039362              NaN   0.021515
# mailq                  0.027501     0.038436              NaN   0.211838
# premiere              -0.026285    -0.028297              NaN  -0.094091
# stucell               -0.003393     0.032075              NaN   0.040369
# ETHNICITY_A            0.056812     0.013059              NaN  -0.009632
# ETHNICITY_B           -0.032275     0.014218              NaN  -0.011936
# ETHNICITY_C           -0.034151     0.004889              NaN   0.088092
# ETHNICITY_H           -0.011984    -0.025178              NaN  -0.172788
# ETHNICITY_I           -0.007251    -0.007278              NaN   0.040724
# ETHNICITY_N            0.051704    -0.004567              NaN   0.026482
# ETHNICITY_O            0.005859     0.006982              NaN   0.012412
# TERRITORY_1           -0.064601    -0.061326              NaN  -0.261387
# TERRITORY_2           -0.084167    -0.079900              NaN   0.259217
# TERRITORY_3           -0.064765    -0.061482              NaN  -0.262499
# TERRITORY_4           -0.069901    -0.066357              NaN  -0.081135
# TERRITORY_5           -0.082143    -0.077979              NaN   0.076567
# TERRITORY_6           -0.063890    -0.060651              NaN  -0.164353
# TERRITORY_7           -0.074247    -0.070483              NaN   0.014043
# TERRITORY_8           -0.054004    -0.051266              NaN   0.071291
# TERRITORY_A            1.000000    -0.035349              NaN   0.246725
# TERRITORY_N           -0.035349     1.000000              NaN   0.232437
# LEVEL_YEAR_FR14             NaN          NaN              NaN        NaN
# Instate_N              0.246725     0.232437              NaN   1.000000
# Instate_Y             -0.246725    -0.232437              NaN  -1.000000
#
#                     Instate_Y
# TOTAL_CONTACTS       0.150889
# SELF_INIT_CNTCTS     0.145825
# TRAVEL_INIT_CNTCTS   0.223375
# SOLICITED_CNTCTS    -0.141391
# REFERRAL_CNTCTS      0.017162
# CAMPUS_VISIT         0.048452
# interest             0.061182
# init_span           -0.069467
# int1rat              0.648097
# int2rat              0.697598
# hscrat               0.147477
# avg_income           0.018108
# distance            -0.629321
# sex                 -0.021515
# mailq               -0.211838
# premiere             0.094091
# stucell             -0.040369
# ETHNICITY_A          0.009632
# ETHNICITY_B          0.011936
# ETHNICITY_C         -0.088092
# ETHNICITY_H          0.172788
# ETHNICITY_I         -0.040724
# ETHNICITY_N         -0.026482
# ETHNICITY_O         -0.012412
# TERRITORY_1          0.261387
# TERRITORY_2         -0.259217
# TERRITORY_3          0.262499
# TERRITORY_4          0.081135
# TERRITORY_5         -0.076567
# TERRITORY_6          0.164353
# TERRITORY_7         -0.014043
# TERRITORY_8         -0.071291
# TERRITORY_A         -0.246725
# TERRITORY_N         -0.232437
# LEVEL_YEAR_FR14           NaN
# Instate_N           -1.000000
# Instate_Y            1.000000
#
# [37 rows x 37 columns]

# %%
#self-initiated contact count is highly correlated with total contact count
#there is also strong correlation between 5-year primary & seconday interest code rate and the instate dummy variable
#we execute the following code to reduce the impact of correlation
x.drop(inplace=True, columns=['TOTAL_CONTACTS','int1rat','int2rat','distance'])
x.corr()
# Out:
#                     SELF_INIT_CNTCTS  TRAVEL_INIT_CNTCTS  SOLICITED_CNTCTS  \
# SELF_INIT_CNTCTS            1.000000            0.059156          0.005819
# TRAVEL_INIT_CNTCTS          0.059156            1.000000         -0.339057
# SOLICITED_CNTCTS            0.005819           -0.339057          1.000000
# REFERRAL_CNTCTS             0.035479           -0.045777         -0.071772
# CAMPUS_VISIT                0.339548            0.002800         -0.026856
# interest                    0.283897            0.105856         -0.008995
# init_span                  -0.041564            0.116931          0.234363
# hscrat                      0.231157           -0.026882         -0.020879
# avg_income                  0.166142           -0.046230         -0.000017
# sex                         0.014408            0.025271          0.059607
# mailq                      -0.114784           -0.706158          0.305282
# premiere                    0.506728            0.061131          0.028984
# stucell                     0.320277            0.033436          0.196754
# ETHNICITY_A                 0.089991           -0.015085          0.013504
# ETHNICITY_B                 0.026817            0.000676          0.008075
# ETHNICITY_C                -0.047444           -0.009831         -0.074437
# ETHNICITY_H                 0.040994            0.153184         -0.099656
# ETHNICITY_I                -0.003158           -0.022046          0.031556
# ETHNICITY_N                -0.026818           -0.075882          0.130032
# ETHNICITY_O                -0.022079           -0.061268          0.073602
# TERRITORY_1                 0.035866            0.054271         -0.024384
# TERRITORY_2                -0.078737           -0.080128          0.080923
# TERRITORY_3                 0.064433            0.046529         -0.061387
# TERRITORY_4                 0.020729            0.010093         -0.022700
# TERRITORY_5                -0.049250            0.003442          0.010579
# TERRITORY_6                 0.022445            0.004337          0.014133
# TERRITORY_7                -0.001170           -0.005776          0.000988
# TERRITORY_8                 0.067189            0.022760          0.010967
# TERRITORY_A                -0.046406           -0.016785          0.020977
# TERRITORY_N                -0.030346           -0.043022         -0.065658
# LEVEL_YEAR_FR14                  NaN                 NaN               NaN
# Instate_N                  -0.145825           -0.223375          0.141391
# Instate_Y                   0.145825            0.223375         -0.141391
#
#                     REFERRAL_CNTCTS  CAMPUS_VISIT  interest  init_span  \
# SELF_INIT_CNTCTS           0.035479      0.339548  0.283897  -0.041564
# TRAVEL_INIT_CNTCTS        -0.045777      0.002800  0.105856   0.116931
# SOLICITED_CNTCTS          -0.071772     -0.026856 -0.008995   0.234363
# REFERRAL_CNTCTS            1.000000      0.016107  0.026995   0.043553
# CAMPUS_VISIT               0.016107      1.000000  0.116649   0.043004
# interest                   0.026995      0.116649  1.000000  -0.005903
# init_span                  0.043553      0.043004 -0.005903   1.000000
# hscrat                     0.024081      0.128340  0.069981  -0.054469
# avg_income                -0.005155      0.111515  0.025576  -0.024922
# sex                       -0.003768      0.007381  0.003143   0.070605
# mailq                      0.035374     -0.145754 -0.155669  -0.074741
# premiere                   0.053778      0.081940  0.139910   0.022478
# stucell                   -0.046132      0.111135  0.133708   0.070911
# ETHNICITY_A               -0.021170      0.004459  0.017117  -0.040332
# ETHNICITY_B               -0.032864     -0.020505  0.030278  -0.009930
# ETHNICITY_C                0.074607      0.054900  0.003616  -0.005370
# ETHNICITY_H               -0.024882     -0.012607  0.036224  -0.054778
# ETHNICITY_I               -0.000988     -0.007937 -0.002414   0.017904
# ETHNICITY_N               -0.035208     -0.039455 -0.062249   0.065874
# ETHNICITY_O               -0.015957     -0.017500 -0.011491   0.025681
# TERRITORY_1               -0.014746      0.014602  0.011922  -0.028968
# TERRITORY_2                0.045975     -0.040130 -0.018401   0.069528
# TERRITORY_3                0.000236      0.018934  0.025335  -0.029673
# TERRITORY_4               -0.018019      0.002926  0.015626  -0.001493
# TERRITORY_5               -0.017425     -0.026007 -0.002101  -0.001722
# TERRITORY_6                0.015940      0.021247  0.007300  -0.012632
# TERRITORY_7               -0.001107     -0.020379 -0.001451   0.010250
# TERRITORY_8                0.002215      0.072992 -0.009292   0.000438
# TERRITORY_A               -0.011439     -0.021918 -0.023101   0.017794
# TERRITORY_N               -0.018408     -0.007569 -0.020975  -0.055284
# LEVEL_YEAR_FR14                 NaN           NaN       NaN        NaN
# Instate_N                 -0.017162     -0.048452 -0.061182   0.069467
# Instate_Y                  0.017162      0.048452  0.061182  -0.069467
#
#                       hscrat  avg_income       sex  ...  TERRITORY_4  \
# SELF_INIT_CNTCTS    0.231157    0.166142  0.014408  ...     0.020729
# TRAVEL_INIT_CNTCTS -0.026882   -0.046230  0.025271  ...     0.010093
# SOLICITED_CNTCTS   -0.020879   -0.000017  0.059607  ...    -0.022700
# REFERRAL_CNTCTS     0.024081   -0.005155 -0.003768  ...    -0.018019
# CAMPUS_VISIT        0.128340    0.111515  0.007381  ...     0.002926
# interest            0.069981    0.025576  0.003143  ...     0.015626
# init_span          -0.054469   -0.024922  0.070605  ...    -0.001493
# hscrat              1.000000    0.223727 -0.020954  ...     0.015659
# avg_income          0.223727    1.000000 -0.018808  ...     0.035706
# sex                -0.020954   -0.018808  1.000000  ...     0.005781
# mailq               0.003202    0.033402 -0.024866  ...    -0.002695
# premiere            0.140447    0.091635  0.013730  ...     0.018781
# stucell             0.094366    0.099173  0.059366  ...    -0.003581
# ETHNICITY_A         0.037783    0.083699 -0.015436  ...    -0.020755
# ETHNICITY_B        -0.049372   -0.097081  0.004924  ...    -0.042986
# ETHNICITY_C         0.043569    0.056008 -0.017547  ...    -0.014788
# ETHNICITY_H        -0.046985   -0.146511  0.009180  ...     0.068115
# ETHNICITY_I        -0.013472   -0.017891 -0.000310  ...    -0.010706
# ETHNICITY_N         0.009726    0.093181  0.014822  ...     0.011605
# ETHNICITY_O        -0.012490   -0.013906  0.011085  ...    -0.005194
# TERRITORY_1         0.057433    0.136926  0.004434  ...    -0.121270
# TERRITORY_2        -0.090914   -0.150238  0.011154  ...    -0.157998
# TERRITORY_3         0.065681    0.078494  0.003067  ...    -0.121577
# TERRITORY_4         0.015659    0.035706  0.005781  ...     1.000000
# TERRITORY_5        -0.075706   -0.172066 -0.000234  ...    -0.154199
# TERRITORY_6         0.046149    0.042960 -0.001746  ...    -0.119934
# TERRITORY_7        -0.029372   -0.008601  0.006990  ...    -0.139377
# TERRITORY_8         0.089999    0.070779 -0.023289  ...    -0.101375
# TERRITORY_A        -0.051351    0.067389  0.016582  ...    -0.069901
# TERRITORY_N         0.004242   -0.000619 -0.039362  ...    -0.066357
# LEVEL_YEAR_FR14          NaN         NaN       NaN  ...          NaN
# Instate_N          -0.147477   -0.018108  0.021515  ...    -0.081135
# Instate_Y           0.147477    0.018108 -0.021515  ...     0.081135
#
#                     TERRITORY_5  TERRITORY_6  TERRITORY_7  TERRITORY_8  \
# SELF_INIT_CNTCTS      -0.049250     0.022445    -0.001170     0.067189
# TRAVEL_INIT_CNTCTS     0.003442     0.004337    -0.005776     0.022760
# SOLICITED_CNTCTS       0.010579     0.014133     0.000988     0.010967
# REFERRAL_CNTCTS       -0.017425     0.015940    -0.001107     0.002215
# CAMPUS_VISIT          -0.026007     0.021247    -0.020379     0.072992
# interest              -0.002101     0.007300    -0.001451    -0.009292
# init_span             -0.001722    -0.012632     0.010250     0.000438
# hscrat                -0.075706     0.046149    -0.029372     0.089999
# avg_income            -0.172066     0.042960    -0.008601     0.070779
# sex                   -0.000234    -0.001746     0.006990    -0.023289
# mailq                  0.004439    -0.010886     0.018805    -0.008691
# premiere              -0.038153     0.023766    -0.015977     0.026115
# stucell               -0.030699    -0.007352     0.014683     0.029410
# ETHNICITY_A           -0.032326    -0.006170     0.001186    -0.003213
# ETHNICITY_B           -0.061322    -0.014311    -0.024060    -0.047440
# ETHNICITY_C            0.010528     0.034454    -0.033039     0.031469
# ETHNICITY_H            0.055013    -0.044970     0.075289    -0.005741
# ETHNICITY_I            0.061101    -0.009244    -0.021049    -0.008777
# ETHNICITY_N           -0.016329     0.008228     0.007844     0.007624
# ETHNICITY_O            0.012183     0.000167    -0.008051    -0.008819
# TERRITORY_1           -0.142508    -0.110841    -0.128810    -0.093689
# TERRITORY_2           -0.185668    -0.144410    -0.167821    -0.122064
# TERRITORY_3           -0.142869    -0.111122    -0.129136    -0.093927
# TERRITORY_4           -0.154199    -0.119934    -0.139377    -0.101375
# TERRITORY_5            1.000000    -0.140939    -0.163786    -0.119129
# TERRITORY_6           -0.140939     1.000000    -0.127391    -0.092658
# TERRITORY_7           -0.163786    -0.127391     1.000000    -0.107678
# TERRITORY_8           -0.119129    -0.092658    -0.107678     1.000000
# TERRITORY_A           -0.082143    -0.063890    -0.074247    -0.054004
# TERRITORY_N           -0.077979    -0.060651    -0.070483    -0.051266
# LEVEL_YEAR_FR14             NaN          NaN          NaN          NaN
# Instate_N              0.076567    -0.164353     0.014043     0.071291
# Instate_Y             -0.076567     0.164353    -0.014043    -0.071291
#
#                     TERRITORY_A  TERRITORY_N  LEVEL_YEAR_FR14  Instate_N  \
# SELF_INIT_CNTCTS      -0.046406    -0.030346              NaN  -0.145825
# TRAVEL_INIT_CNTCTS    -0.016785    -0.043022              NaN  -0.223375
# SOLICITED_CNTCTS       0.020977    -0.065658              NaN   0.141391
# REFERRAL_CNTCTS       -0.011439    -0.018408              NaN  -0.017162
# CAMPUS_VISIT          -0.021918    -0.007569              NaN  -0.048452
# interest              -0.023101    -0.020975              NaN  -0.061182
# init_span              0.017794    -0.055284              NaN   0.069467
# hscrat                -0.051351     0.004242              NaN  -0.147477
# avg_income             0.067389    -0.000619              NaN  -0.018108
# sex                    0.016582    -0.039362              NaN   0.021515
# mailq                  0.027501     0.038436              NaN   0.211838
# premiere              -0.026285    -0.028297              NaN  -0.094091
# stucell               -0.003393     0.032075              NaN   0.040369
# ETHNICITY_A            0.056812     0.013059              NaN  -0.009632
# ETHNICITY_B           -0.032275     0.014218              NaN  -0.011936
# ETHNICITY_C           -0.034151     0.004889              NaN   0.088092
# ETHNICITY_H           -0.011984    -0.025178              NaN  -0.172788
# ETHNICITY_I           -0.007251    -0.007278              NaN   0.040724
# ETHNICITY_N            0.051704    -0.004567              NaN   0.026482
# ETHNICITY_O            0.005859     0.006982              NaN   0.012412
# TERRITORY_1           -0.064601    -0.061326              NaN  -0.261387
# TERRITORY_2           -0.084167    -0.079900              NaN   0.259217
# TERRITORY_3           -0.064765    -0.061482              NaN  -0.262499
# TERRITORY_4           -0.069901    -0.066357              NaN  -0.081135
# TERRITORY_5           -0.082143    -0.077979              NaN   0.076567
# TERRITORY_6           -0.063890    -0.060651              NaN  -0.164353
# TERRITORY_7           -0.074247    -0.070483              NaN   0.014043
# TERRITORY_8           -0.054004    -0.051266              NaN   0.071291
# TERRITORY_A            1.000000    -0.035349              NaN   0.246725
# TERRITORY_N           -0.035349     1.000000              NaN   0.232437
# LEVEL_YEAR_FR14             NaN          NaN              NaN        NaN
# Instate_N              0.246725     0.232437              NaN   1.000000
# Instate_Y             -0.246725    -0.232437              NaN  -1.000000
#
#                     Instate_Y
# SELF_INIT_CNTCTS     0.145825
# TRAVEL_INIT_CNTCTS   0.223375
# SOLICITED_CNTCTS    -0.141391
# REFERRAL_CNTCTS      0.017162
# CAMPUS_VISIT         0.048452
# interest             0.061182
# init_span           -0.069467
# hscrat               0.147477
# avg_income           0.018108
# sex                 -0.021515
# mailq               -0.211838
# premiere             0.094091
# stucell             -0.040369
# ETHNICITY_A          0.009632
# ETHNICITY_B          0.011936
# ETHNICITY_C         -0.088092
# ETHNICITY_H          0.172788
# ETHNICITY_I         -0.040724
# ETHNICITY_N         -0.026482
# ETHNICITY_O         -0.012412
# TERRITORY_1          0.261387
# TERRITORY_2         -0.259217
# TERRITORY_3          0.262499
# TERRITORY_4          0.081135
# TERRITORY_5         -0.076567
# TERRITORY_6          0.164353
# TERRITORY_7         -0.014043
# TERRITORY_8         -0.071291
# TERRITORY_A         -0.246725
# TERRITORY_N         -0.232437
# LEVEL_YEAR_FR14           NaN
# Instate_N           -1.000000
# Instate_Y            1.000000
#
# [33 rows x 33 columns]

# %%
#Data Partitioning
y = df['Enroll'] #dependent variable
x_train,x_val,y_train,y_val=train_test_split(x,y,test_size=0.3,random_state=4)

# %%
#fit a logistic model to the data
log_reg = sm.Logit(y_train,x_train).fit(maxiter=400)
print(log_reg.summary())
# Out:
# Warning: Maximum number of iterations has been exceeded.
#          Current function value: 0.060567
#          Iterations: 400
# c:\Users\tomsh\anaconda3\envs\DSBA\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                 Enroll   No. Observations:                64033
# Model:                          Logit   Df Residuals:                    64003
# Method:                           MLE   Df Model:                           29
# Date:                Thu, 18 May 2023   Pseudo R-squ.:                  0.5683
# Time:                        00:29:09   Log-Likelihood:                -3878.3
# converged:                      False   LL-Null:                       -8983.2
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ======================================================================================
#                          coef    std err          z      P>|z|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# SELF_INIT_CNTCTS       0.4490      0.015     29.662      0.000       0.419       0.479
# TRAVEL_INIT_CNTCTS     0.3438      0.055      6.245      0.000       0.236       0.452
# SOLICITED_CNTCTS       0.0125      0.040      0.311      0.756      -0.067       0.092
# REFERRAL_CNTCTS        0.3419      0.109      3.134      0.002       0.128       0.556
# CAMPUS_VISIT           0.9808      0.085     11.514      0.000       0.814       1.148
# interest               0.3973      0.069      5.789      0.000       0.263       0.532
# init_span             -0.0460      0.005    -10.027      0.000      -0.055      -0.037
# hscrat                12.0890      0.432     27.974      0.000      11.242      12.936
# avg_income         -2.647e-07   1.52e-06     -0.174      0.862   -3.25e-06    2.72e-06
# sex                   -0.3223      0.064     -5.041      0.000      -0.448      -0.197
# mailq                  0.1793      0.023      7.719      0.000       0.134       0.225
# premiere               1.2021      0.085     14.166      0.000       1.036       1.368
# stucell               34.6738   1.05e+06    3.3e-05      1.000   -2.06e+06    2.06e+06
# ETHNICITY_A           -2.7862   1.62e+06  -1.72e-06      1.000   -3.18e+06    3.18e+06
# ETHNICITY_B           -3.1534   1.61e+06  -1.96e-06      1.000   -3.15e+06    3.15e+06
# ETHNICITY_C           -2.9327   1.62e+06  -1.81e-06      1.000   -3.18e+06    3.18e+06
# ETHNICITY_H           -2.9690   1.83e+06  -1.62e-06      1.000   -3.59e+06    3.59e+06
# ETHNICITY_I           -3.3295    1.6e+06  -2.08e-06      1.000   -3.14e+06    3.14e+06
# ETHNICITY_N           -4.9946   1.62e+06  -3.07e-06      1.000   -3.18e+06    3.18e+06
# ETHNICITY_O           -2.9831   1.72e+06  -1.74e-06      1.000   -3.37e+06    3.37e+06
# TERRITORY_1           -1.9685        nan        nan        nan         nan         nan
# TERRITORY_2           -2.2027        nan        nan        nan         nan         nan
# TERRITORY_3           -2.0773        nan        nan        nan         nan         nan
# TERRITORY_4           -2.1662        nan        nan        nan         nan         nan
# TERRITORY_5           -1.8036        nan        nan        nan         nan         nan
# TERRITORY_6           -2.1087        nan        nan        nan         nan         nan
# TERRITORY_7           -2.1497        nan        nan        nan         nan         nan
# TERRITORY_8           -2.5715        nan        nan        nan         nan         nan
# TERRITORY_A           -2.0396        nan        nan        nan         nan         nan
# TERRITORY_N           -4.0605        nan        nan        nan         nan         nan
# LEVEL_YEAR_FR14      -23.1484        nan        nan        nan         nan         nan
# Instate_N            -11.9077        nan        nan        nan         nan         nan
# Instate_Y            -11.2407        nan        nan        nan         nan         nan
# ======================================================================================
#
# Possibly complete quasi-separation: A fraction 0.51 of observations can be
# perfectly predicted. This might indicate that there is complete
# quasi-separation. In this case some parameters will not be identified.

# %%
# Model Evaluation using accuracy & confusion matrix
pred =log_reg.predict(x_val)
prediction =list(map(round,pred))
cm = confusion_matrix(y_val,prediction)
disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
# plt.show()
accuracy_score(y_val,prediction)
# Out:
# 0.975950151222534

# %%
# model evaluation using roc curve
lr_auc = roc_auc_score(y_val,pred)
print('Logistic: ROC AUC =%.3f' % (lr_auc))
lr_fpr, lr_tpr, threshold = roc_curve(y_val,pred)
plt.plot(lr_fpr,lr_tpr,marker='.')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.show()
# Out:
# Logistic: ROC AUC =0.978
# Text(0.5, 0, 'False Positive Rate')
# Text(0, 0.5, 'True Positive Rate')

# %%
kds.metrics.plot_cumulative_gain(y_val, pred)
